# %%
# %pip install yelpapi
from yelpapi import YelpAPI
import json
import pandas as pd
# Out:
# Requirement already satisfied: yelpapi in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (2.5.0)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
with open('/Users/jasontracey/.secret/yelp_api.json') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['Client ID', 'API Key', 'businesses', 'total', 'region'])

# %%
yelp_api = YelpAPI(login['API Key'], timeout_s=5.0)
yelp_api

# %%
sushi_0 = yelp_api.search_query(location='Greenville, SC',
                                       term='Sushi')
type(sushi_0)
sushi_0.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
sushi0 = pd.DataFrame(sushi_0['businesses'])
sushi0.head(2)
# Out:
#                        id                             alias  \
# 0  RGRk1ioORwm_FIX8PM732Q             konnichiwa-greenville
# 1  babpQQHQSGjVxS1Li7Q2lA  otto-izakaya-downtown-greenville
#
#                       name                                          image_url  \
# 0               Konnichiwa  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...
# 1  Otto Izakaya - Downtown  https://s3-media1.fl.yelpcdn.com/bphoto/wkiY2M...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/konnichiwa-greenville...            49
# 1      False  https://www.yelp.com/biz/otto-izakaya-downtown...           160
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 1  [{'alias': 'izakaya', 'title': 'Izakaya'}, {'a...     4.0
#
#                                          coordinates  \
# 0  {'latitude': 34.845952342825115, 'longitude': ...
# 1       {'latitude': 34.84428, 'longitude': -82.406}
#
#                          transactions  \
# 0                                  []
# 1  [restaurant_reservation, delivery]
#
#                                             location         phone  \
# 0  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
# 1  {'address1': '802 S Main St', 'address2': '', ...  +18645685880
#
#     display_phone     distance price
# 0  (864) 252-4436  4108.206391   NaN
# 1  (864) 568-5880  4269.838700    $$

# %%
sushi_0['total']
# Out:
# 105

# %%
sushi_20 = yelp_api.search_query(location='Greenville, SC', term='sushi',
                                 offset = 20)

# %%
sushi20 = pd.DataFrame(sushi_20['businesses'])
sushi20.head(2)
# Out:
#                        id                          alias              name  \
# 0  dMx4q_Px48Qw_tJm_EGzUA  koi-asian-bistro-greenville-2  Koi Asian Bistro
# 1  0NNl-TjwwDkRl0oAZK4p3A           sushi-asa-greenville         Sushi Asa
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/AsRMU_...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/xEYZ7_...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/koi-asian-bistro-gree...           142
# 1  https://www.yelp.com/biz/sushi-asa-greenville?...           138
#
#                                           categories  rating  \
# 0  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.0
# 1        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 34.86791615887092, 'longitude': -...            [pickup]
# 1  {'latitude': 34.8171189, 'longitude': -82.2755...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '115 Pelham Rd', 'address2': 'Ste...  +18642415355
# 1    $$  {'address1': '150 Tanner Rd', 'address2': None...  +18642885259
#
#     display_phone     distance
# 0  (864) 241-5355  3967.677457
# 1  (864) 288-5259  8150.554706

# %%
all_sushi = pd.concat([sushi0, sushi20],
                      ignore_index=True)
display(all_sushi.head(3), all_sushi.tail(3))
# Out:
#                        id                             alias  \
# 0  RGRk1ioORwm_FIX8PM732Q             konnichiwa-greenville
# 1  babpQQHQSGjVxS1Li7Q2lA  otto-izakaya-downtown-greenville
# 2  7cJxOV-ANX1qLThK3yV96w         otto-izakaya-greenville-4
#
#                       name                                          image_url  \
# 0               Konnichiwa  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...
# 1  Otto Izakaya - Downtown  https://s3-media1.fl.yelpcdn.com/bphoto/wkiY2M...
# 2             Otto Izakaya  https://s3-media1.fl.yelpcdn.com/bphoto/TdPhFy...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/konnichiwa-greenville...            49
# 1      False  https://www.yelp.com/biz/otto-izakaya-downtown...           160
# 2      False  https://www.yelp.com/biz/otto-izakaya-greenvil...           435
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 1  [{'alias': 'izakaya', 'title': 'Izakaya'}, {'a...     4.0
# 2  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
#
#                                          coordinates  \
# 0  {'latitude': 34.845952342825115, 'longitude': ...
# 1       {'latitude': 34.84428, 'longitude': -82.406}
# 2  {'latitude': 34.8228218820722, 'longitude': -8...
#
#                          transactions  \
# 0                                  []
# 1  [restaurant_reservation, delivery]
# 2                          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
# 1  {'address1': '802 S Main St', 'address2': '', ...  +18645685880
# 2  {'address1': '15 Market Point Dr', 'address2':...  +18645688009
#
#     display_phone     distance price
# 0  (864) 252-4436  4108.206391   NaN
# 1  (864) 568-5880  4269.838700    $$
# 2  (864) 568-8009  5695.017446    $$
#                         id                                              alias  \
# 37  Mh9a3Zc78w46m02fCgVY-A             asia-pacific-super-market-greenville-3
# 38  msWJkhRnS5rgYnwn8OoM4g                         kanpai-of-toyko-greenville
# 39  MIjm6YwbBlPWXWH3YTiSlQ  samurai-japanese-steakhouse-and-cajun-seafood-...
#
#                                            name  \
# 37                    Asia Pacific Super Market
# 38                              Kanpai of Toyko
# 39  Samurai Japanese Steakhouse & Cajun Seafood
#
#                                             image_url  is_closed  \
# 37  https://s3-media1.fl.yelpcdn.com/bphoto/C0McWe...      False
# 38  https://s3-media1.fl.yelpcdn.com/bphoto/RvJy17...      False
# 39  https://s3-media3.fl.yelpcdn.com/bphoto/kKirQe...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/asia-pacific-super-ma...           186
# 38  https://www.yelp.com/biz/kanpai-of-toyko-green...           129
# 39  https://www.yelp.com/biz/samurai-japanese-stea...            20
#
#                                            categories  rating  \
# 37  [{'alias': 'intlgrocery', 'title': 'Internatio...     4.5
# 38  [{'alias': 'japanese', 'title': 'Japanese'}, {...     2.0
# 39  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
#
#                                           coordinates        transactions  \
# 37     {'latitude': 34.85289, 'longitude': -82.35708}          [delivery]
# 38  {'latitude': 34.8464317321777, 'longitude': -8...          [delivery]
# 39      {'latitude': 34.85835, 'longitude': -82.2661}  [pickup, delivery]
#
#                                              location         phone  \
# 37  {'address1': '420 N Pleasantburg Dr', 'address...  +18646031377
# 38  {'address1': '533 Haywood Rd', 'address2': '',...  +18642340334
# 39  {'address1': '102 East Beacon Dr', 'address2':...  +18642361775
#
#      display_phone     distance price
# 37  (864) 603-1377  2245.752444    $$
# 38  (864) 234-0334  2339.964345    $$
# 39  (864) 236-1775  9080.170805   NaN

# %%
all_sushi.to_json(orient='records')
# Out:
# '[{"id":"RGRk1ioORwm_FIX8PM732Q","alias":"konnichiwa-greenville","name":"Konnichiwa","image_url":"https:\\/\\/s3-media3.fl.yelpcdn.com\\/bphoto\\/p47H0_yyd8XVBVi70rE3dw\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/konnichiwa-greenville?adjust_creative=cJ0NqYANhAi_b9jOTQTNaQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cJ0NqYANhAi_b9jOTQTNaQ","review_count":49,"categories":[{"alias":"sushi","title":"Sushi Bars"},{"alias":"japanese","title":"Japanese"}],"rating":4.0,"coordinates":{"latitude":34.8459523428,"longitude":-82.4034447},"transactions":[],"location":{"address1":"101 Falls Park Dr","address2":"Ste 100","address3":null,"city":"Greenville","zip_code":"29601","country":"US","state":"SC","display_address":["101 Falls Park Dr","Ste 100","Greenville, SC 29601"]},"phone":"+18642524436","display_phone":"(864) 252-4436","distance":4108.2063909746,"price":null},{"id":"babpQQHQSGjVxS1Li7Q2lA","alias":"otto-izakaya-downtown-greenville","name":"Otto Izakaya - Downtown","image_url":"https:\\/\\/s3-media1.fl.yelpcdn.com\\/bphoto\\/wkiY2MFOKy9O1mO3JCShlA\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/otto-izakaya-downtown-greenville?adjust_creative=cJ0NqYANhAi_b9jOTQTNaQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cJ0NqYANhAi_b9jOTQTNaQ","review_count":160,"categories":[{"alias":"izakaya","title":"Izakaya"},{"alias":"sushi","title":"Sushi Bars"},{"alias":"korean","title":"Korean"}],"rating":4.0,"coordinates":{"latitude":34.84428,"longitude":-82.406},"transactions":["restaurant_reservation","delivery"],"location":{"address1":"802 S Main St","address2":"","address3":null,"city":"Greenville","zip_code":"29601","country":"US","state":"SC","display_address":["802 S Main St","Greenville, SC 29601"]},"phone":"+18645685880","display_phone":"(864) 568-5880","distance":4269.8386995014,"price":"$$"},{"id":"7cJxOV-ANX1qLThK3yV96w","alias":"otto-izakaya-greenville-4","name":"Otto Izakaya","image_url":"https:\\/\\/s3-media1.fl.yelpcdn.com\\/bphoto\\/TdPhFy6jy-Aaww5vzlaQzQ\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/otto-izakaya-greenville-4?adjust_creative=cJ0NqYANhAi_b9jOTQTNaQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cJ0NqYANhAi_b9jOTQTNaQ","review_count":435,"categories":[{"alias":"japanese","title":"Japanese"},{"alias":"gastropubs","title":"Gastropubs"},{"alias":"sushi","title":"Sushi Bars"}],"rating":4.0,"coordinates":{"latitude":34.8228218821,"longitude":-82.3000437297},"transactions":["delivery"],"location":{"address1":"15 Market Point Dr","address2":"","address3":null,"city":"Greenville","zip_code":"29607","country":"US","state":"SC","display_address":["15 Market Point Dr","Greenville, SC 29607"]},"phone":"+18645688009","display_phone":"(864) 568-8009","distance":5695.0174457929,"price":"$$"},{"id":"Gx1IhUJPwgTVQcJmw1kD0A","alias":"sushi-kingdom-greenville-2","name":"Sushi Kingdom","image_url":"https:\\/\\/s3-media4.fl.yelpcdn.com\\/bphoto\\/O7Y4XjqND5-4eHNZ1Mhz9g\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/sushi-kingdom-greenville-2?adjust_creative=cJ0NqYANhAi_b9jOTQTNaQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cJ0NqYANhAi_b9jOTQTNaQ","review_count":55,"categories":[{"alias":"sushi","title":"Sushi Bars"}],"rating":4.0,"coordinates":{"latitude":34.8332528205,"longitude":-82.3021969},"transactions":["delivery","pickup"],"location":{"address1":"1117 Woodruff Rd","address2":"Ste A","address3":"","city":"Greenville","zip_code":"29607","country":"US","state":"SC","display_address":["1117 Woodruff Rd","Ste A","Greenville, SC 29607"]},"phone":"+18642438313","display_phone":"(864) 243-8313","distance":5373.3276712284,"price":null},{"id":"zG_XOAFi9Y560WJ1RvghBw","alias":"sushi-masa-japanese-restaurant-greenville","name":"Sushi-Masa Japanese Restaurant","image_url":"https:\\/\\/s3-media1.fl.yelpcdn.com\\/bphoto\\/zsRavZs-TIXmIYZYYm9-ew\\/o.jpg","is_closed":fa ...
